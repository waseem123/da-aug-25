# %%
import matplotlib.pyplot as plt

# %%
x = ['Alex','John','Peter','Roger','Sam','Bob','Alice']
y = [74,98,85,87,64,67,99]

# %%
plt.bar(x,y,color="red")
plt.xlabel("Students")
plt.ylabel("Marks")
# Out:
# Text(0, 0.5, 'Marks')
